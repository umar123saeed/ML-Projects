# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import metrics
from sklearn.svm import SVC
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Zillow.csv')
df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  14297519                    NaN                       NaN           NaN
# 1  17052889                    NaN                       NaN           NaN
# 2  14186244                    NaN                       NaN           NaN
# 3  12177905                    NaN                       NaN           NaN
# 4  10887214                    1.0                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          3.5         4.0                  NaN                    NaN
# 1          1.0         2.0                  NaN                    NaN
# 2          2.0         3.0                  NaN                    NaN
# 3          3.0         4.0                  NaN                    8.0
# 4          3.0         3.0                  NaN                    8.0
#
#    calculatedbathnbr  decktypeid  ...  fireplaceflag  \
# 0                3.5         NaN  ...            NaN
# 1                1.0         NaN  ...            NaN
# 2                2.0         NaN  ...            NaN
# 3                3.0         NaN  ...            NaN
# 4                3.0         NaN  ...            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    485713.0          1023282.0          2016.0
# 1                     88000.0           464000.0          2016.0
# 2                     85289.0           564778.0          2016.0
# 3                    108918.0           145143.0          2016.0
# 4                     73681.0           119407.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               537569.0   11013.72                 NaN                 NaN
# 1               376000.0    5672.48                 NaN                 NaN
# 2               479489.0    6488.30                 NaN                 NaN
# 3                36225.0    1777.51                 NaN                 NaN
# 4                45726.0    1533.89                 NaN                 NaN
#
#    censustractandblock    target
# 0         6.059063e+13  0.025595
# 1         6.111001e+13  0.055619
# 2         6.059022e+13  0.005383
# 3         6.037300e+13 -0.103410
# 4         6.037124e+13  0.006940
#
# [5 rows x 59 columns]

# %%
df.shape
# Out:
# (8599, 59)

# %%
to_remove = []
for col in df.columns:

    # Removing columns having only one value.
    if df[col].nunique() == 1:
        to_remove.append(col)

    # Removing columns with more than 90% of the
    # rows as null values.
    elif (df[col].isnull()).mean() > 0.60:
        to_remove.append(col)

print(len(to_remove))
# Out:
# 30

# %%
df.drop(to_remove,
        axis=1,
        inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8599 entries, 0 to 8598
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      8599 non-null   int64
#  1   bathroomcnt                   8593 non-null   float64
#  2   bedroomcnt                    8593 non-null   float64
#  3   buildingqualitytypeid         5576 non-null   float64
#  4   calculatedbathnbr             8536 non-null   float64
#  5   calculatedfinishedsquarefeet  8573 non-null   float64
#  6   finishedsquarefeet12          8128 non-null   float64
#  7   fips                          8593 non-null   float64
#  8   fullbathcnt                   8536 non-null   float64
#  9   heatingorsystemtypeid         5502 non-null   float64
#  10  latitude                      8593 non-null   float64
#  11  longitude                     8593 non-null   float64
#  12  lotsizesquarefeet             7636 non-null   float64
#  13  propertycountylandusecode     8593 non-null   object
#  14  propertylandusetypeid         8593 non-null   float64
#  15  propertyzoningdesc            5652 non-null   object
#  16  rawcensustractandblock        8593 non-null   float64
#  17  regionidcity                  8449 non-null   float64
#  18  regionidcounty                8593 non-null   float64
#  19  regionidzip                   8586 non-null   float64
#  20  roomcnt                       8593 non-null   float64
#  21  unitcnt                       5673 non-null   float64
#  22  yearbuilt                     8567 non-null   float64
#  23  structuretaxvaluedollarcnt    8576 non-null   float64
#  24  taxvaluedollarcnt             8593 non-null   float64
#  25  landtaxvaluedollarcnt         8593 non-null   float64
#  26  taxamount                     8592 non-null   float64
#  27  censustractandblock           8572 non-null   float64
#  28  target                        8599 non-null   float64
# dtypes: float64(26), int64(1), object(2)
# memory usage: 1.9+ MB

# %%
df.isnull().sum().plot.bar()
plt.show()

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].fillna(df[col].mode()[0])
    elif df[col].dtype == np.number:
        df[col] = df[col].fillna(df[col].mean())

df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
ints, objects, floats = [], [], []

for col in df.columns:
    if df[col].dtype == float:
        floats.append(col)
    elif df[col].dtype == int:
        ints.append(col)
    else:
        objects.append(col)

len(ints), len(floats), len(objects)
# Out:
# (1, 26, 2)

# %%
for col in objects:
    print(col, ' -> ', df[col].nunique())
    print(df[col].unique())
    print()
# Out:
# propertycountylandusecode  ->  47
# ['122' '1110' '101' '010C' '1129' '100' '38' '34' '1111' '012C' '010V' '1'
#  '103' '010D' '200' '010E' '300' '96' '104' '400' '01DC' '01HC' '1321'
#  '1410' '108' '1128' '010G' '1720' '010H' '1210' '102' '010F' '010M'
#  '1117' '201' '700' '1722' '73' '109' '301' '01HE' '135' '204' '401'
#  '070D' '113' '133']
#
# propertyzoningdesc  ->  886
# ['LAR1' 'LCR110000*' 'LAR3' 'PSR2' 'GLR4YY' 'WHRE20000*' 'SCUR2' 'GLR3*'
#  'LCR2YY' 'PARM*' 'LAC2' 'LARD3' 'LBR1S' 'LARD1.5' 'RPRS10000*' 'LCA11*'
#  'LFR120000*' 'LARE9' 'PSR*' 'PSR3' 'INP1YY' 'GDRHR' 'GDR_GA_PD' 'LARE11'
#  'LCA105' 'LAR2' 'TCR1*' 'LBR1L' 'LCR3*' 'LCA11L' 'WARPD14800' 'LARS'
#  'LACW' 'POR17200*' 'POR31000*' 'WAC3*' 'LVRSP87-19' 'LKR1YY' 'HHRAS1*'
#  'SCUR3' 'CARS*' 'LARD2' 'BUR1YY' 'BHR4*' 'LBR2N' 'LARE15' 'LCR315U*'
#  'SPR310000*' 'BFR1YY' 'LRR7000*' 'DOR106' 'LCRPD60005' 'LCA1*' 'LAC5'
#  'MNR1YY' 'PSR4' 'CEADP3' 'LARA' 'GDE4' 'CERS5000' 'PSR6' 'WARPD16800'
#  'SCSP' 'POPRD*' 'INR1YY' 'LVPR2D*' 'ALRPD*' 'PRSF*' 'PDR17500*' 'PDR1*'
#  'LYR3YY' 'LCA25*' 'BGR3*' 'SCCP' 'LCR175' 'SLR1YY' 'PDRI 7000'
#  'LCA110000*' 'CORL*' 'COR1*' 'ARROD*' 'ARR0*' 'ARRO*' 'PDSP*' 'LRMD2'
#  'DOR105' 'PDRPD-3U*' 'LCA21*' 'ARR1YY' 'BGA1*' 'LCR2*' 'LRRA7000*' 'SCOS'
#  'EMR3*' 'LBR4N' 'NOR1YY' 'LCRA1*' 'SMR1*' 'GLR1YY' 'SSR3PD*' 'LCC3*'
#  'LAA1' 'LCRA75' 'CCR4*' 'LKR1*' 'LBR34' 'LCC1YY' 'LCR1YY' 'LBR1N' 'LCR1*'
#  'GLR4*' 'LCR317UDP*' 'LBPD6' 'LAR5' 'LAWC' 'LARE20' 'AVU*' 'LBPD5' 'SEC*'
#  'LCRPD80009' 'LBR4R' 'LBPD11' 'MNRS' 'SDSFH*' 'BFR2*' 'WCR17500*'
#  'POR3YY' 'POR16000*' 'ESR1YY' 'MNRM' 'DUC1YY' 'TORR-LO' 'INC2*' 'RMPD*'
#  'CVM1' 'GAR1' 'LBR2S' 'MPR2*' 'LCRA2L' 'RPRS13000*' 'LORVD1500*' 'INR3*'
#  'RBMDR*' 'RBR-1' 'GAR3' 'WCR114400*' 'LCRPD50003' 'LCM1*' 'WDR2*' 'GDR2'
#  'HAR3YY' 'HAR3*' 'WCR1YY' 'TOPR-MD' 'LAR4' 'LCR320U*' 'AZP*' 'GDR1'
#  'MPR1YY' 'SOR112' 'LCA106' 'LRD21*' 'LCRPD15000' 'MNR3YY' 'LCR1-R3*'
#  'WVRPD18U*' 'WHR1*' 'LCR18000*' 'LCRA15' 'BFR2PD*' 'LCRPD10000'
#  'WHR171/2' 'WHR17200*' 'LRSP80-01*' 'WHR16000*' 'LCR18500*' 'WCR19450*'
#  'DOR15000*' 'LYR1YY' 'SMR2*' 'LCPR*' 'LVPR10A*' 'RERPD6U*' 'LCRPD20000'
#  'MPR1*' 'CORM*' 'NOR105' 'LCR120000*' 'WASP1*' 'PDA1' 'LYR2*' 'NOR1VV'
#  'LRRA10000*' 'LBPD30' 'ARR1*' 'SCUR1' 'SFR1*' 'GLR1RY' 'GLR1R*'
#  'LCR171/2' 'SLR1*' 'LCR115000*' 'GLR1*' 'PSR1' 'SCNU5' 'SCUR5' 'LAC4'
#  'SLR2YY' 'LCA140000*' 'BLR3YY' 'SRR175' 'POR1*' 'SDSF10000&' 'RBR-1A'
#  'CCR3*' 'POM*' 'MYR3PY' 'BLR3*' 'CVR17500*' 'CVR18500*' 'LNR2YY' 'RMR1*'
#  'AZR1CY' 'AZR3B*' 'GDC2CC*' 'PSC-' 'GDR4*' 'TCR172' 'WCR3-MF25*'
#  'DUR16500*' 'MNR1*' 'EMC3*' 'POR172' 'WHR172' 'CLRS8000*' 'PVR1*'
#  'RBPDR*' 'RBR-3A' 'CCPD*' 'LCR11L' 'LARD6' 'BUR1*' 'CARM25U&D*' 'WDR4*'
#  'LBCO' 'LOR1*' 'BUR4*' 'LBPD10' 'SSR1YY' 'LCRPD90005' 'WVR3' 'LARD4'
#  'GLRA*' 'LCRA06' 'LCA175' 'LPR1YY' 'CCR1AY' 'HBR1*' 'HBR1YY' 'LCRA15000*'
#  'LCR17500*' 'BFER3*' 'GLR3R*' 'SHR2*' 'NOR1*' 'LMPUD*' 'LCR120000-'
#  'WHR1YY' 'DOR1&HFB*' 'LRRA7000-R' 'LCA2' 'SGR4*' 'LCRA7000*' 'ALR1*'
#  'HPR3YY' 'PDRPD1OU*' 'LCRA40000*' 'SCCR' 'LRR110000*' 'COPRH*'
#  'LRR10000*' 'AHR335U*' 'TCR3YY' 'AHRPD51U*' 'COML' 'LRRA7500*' 'PAR1YY'
#  'PAM1' 'LCA22-A25*' 'PDRPD12U*' 'LARD5' 'LCA22*' 'LCR4*' 'LCA15*'
#  'RPRS20000S' 'PDA2*' 'POR1YY' 'POT3YY' 'MPR3*' 'POR3*' 'LCA210-A22'
#  'MNRH' 'POR4*' 'SHR4*' 'NOC1*' 'PDR2*' 'RMR2YY' 'MNR3D17H25' 'WHR106'
#  'LRR6000*' 'GACSP' 'LCRA10000*' 'TORR-MD' 'LRR17000*' 'LNR2PY' 'SGR1YY'
#  'HAR1YY' 'ARR1D*' 'AZR1C*' 'LCR110000D' 'SRR2*' 'PSCD8*' 'LVPR8A*'
#  'INP1VV' 'LRR7000' 'WCR1-PCD1*' 'LRR326.5U*' 'LRRA 7000' 'LRSRR*' 'LBR3T'
#  'LRR366UDP*' 'BPR1*' 'MYR3YY' 'EMR3YY' 'BPR3' 'EMR1C*' 'SDSF7500*'
#  'CVR175' 'LRA22*' 'LAC1.5' 'LCC2*' 'HGR2*' 'CLRA1*' 'WAR17200*'
#  'SPR110000*' 'PDR3-8U*' 'LBR2L' 'LCA15000*' 'LCA16000' 'SDSP4*' 'LRR2*'
#  'CA&MUR&D*' 'CASP-4*' 'PVR1YY' 'LRRPD10000' 'CVR110000*' 'GDE5' 'LCA12*'
#  'LCA110000D' 'WCPCD1*' 'LCR1' 'LRRA6500*' 'LCR3800030' 'LRR16500*'
#  'RPRS-4*' 'EMR1A*' 'LCRA62' 'PDR17000' 'LMR1*' 'WHR105' 'LCRPD60007'
#  'POR2*' 'RBR-3' 'LCR106' 'LCRA7500*' 'AZR1' 'MORH*' 'CMR1YY' 'LCR305'
#  'SHR4' 'DOR1*' 'LCRA05' 'BFR105' 'TCR4*' 'DOR3*' 'LYR1*' 'LCA1YY'
#  'BHR4YY' 'LCR3YY' 'PRR1*' 'HPR1YY' 'LARE40' 'ARR11000D*' 'AHRPD15000'
#  'SOR120' 'SCUR4' 'WHR120000*' 'SOR122500*' 'RPRS20000*' 'NORI YY' 'SRR1*'
#  'TCR105' 'LOR3*' 'SER1*' 'AHR17000*' 'WCRA9450*' 'DOR16000*' 'LRR1*'
#  'DOCP*' 'PDSP' 'HAR2*' 'ATA10000*' 'BPR3*' 'INCR*' 'MORE*' 'MOP/QP*'
#  'MNR3*' 'PDR17000*' 'LCC1*' 'HBPDR*' 'AHRPD70006' 'RMR1YY' 'POT3*'
#  'PDR112000*' 'LCRPD60002' 'WDR3C*' 'CARM25U*' 'TORR-MH' 'CLRS10000*'
#  'SOR19000*' 'ALCBD/DRD*' 'CLHC*' 'HBR2YY' 'SGR2YY' 'WHR17500*' 'MORL*'
#  'LCA210*' 'LCA11Y' 'LCR16000*' 'G1R1*' 'LCRR*' 'LCC3-A1700' 'PRRM*'
#  'SOR109*' 'DOR17500*' 'PDRPD15U*' 'PDA1*' 'SPR1*' 'LBR3S' 'LR-R10000'
#  'SDSF8000*' 'SSR1' 'ARR3*' 'ARR2*' 'LACM' 'LRR17500*' 'SDRA10000*' 'CERM'
#  'WVRPD12U-R' 'WCR3*' 'BPRG*' 'WCR1*' 'CARM12U&D*' 'LCR108' 'AVR3*' 'PDA2'
#  'LCR330U*' 'LCR14L' 'MNRPD' 'LRR36.6UDP' 'LCA16000*' 'LBPD29' 'PAC3YY'
#  'SGR3YY' 'CMR3*' 'POR311/2' 'LCRA1L' 'LVPID*' 'WCPCD1&H*' 'CORH*' 'LMC4*'
#  'GDR3' 'GDE6' 'HBR3*' 'NOR1(R3)*' 'AZR2-RIA*' 'LCR1L2' 'WCPCD110DU'
#  'RPRSIRPD*' 'AZR3C1200*' 'LCR105' 'LACM(GM)' 'SOR109' 'LAOS' 'POR3 1500'
#  'DOR15OOO*' 'R3' 'MOM*' 'HBR3' 'SDSFA10000' 'CLRS13000*' 'INR4*' 'PRRE*'
#  'WAC3-RPD28' 'WCR1AD1*' 'ATR16000*' 'INR2YY' 'GDE6_PD4' 'INR3YY' 'LCA22'
#  'RMR3*' 'SRR3CC*' 'BUR1H*' 'LRM11/2-B1' 'LRRA6000*' 'LR-R1OOOO'
#  'LCR19500*' 'SGR1*' 'PDPS' 'LYR3*' 'LRR3*' 'LCRA30000*' 'PDMPD-RPD1'
#  'COPRM*' 'PDR1-7000' 'PDA11*' 'WDR1B*' 'CVR181/2' 'LBPD1' 'SDSF7500(R'
#  'LAC2(PV)' 'LAC1' 'ESR3' 'NOR15000*' 'WCR3-MF15(' 'RECG' 'SDSFA20000'
#  'CVR1*' 'LCRPD50002' 'RPRS' 'EMR1*' 'WCMF15*' 'RPOH&E*' 'WHR4*' 'EMC4*'
#  'MORM*' 'LCA1' 'PDA21*' 'DUC4YY' 'LAC4(OX)' 'LCRPD60001' 'HPR4YY'
#  'CVR3-RD200' 'LAR1-1(T)-' 'LCRA6000*' 'CVR3-RD150' 'LPR3*' 'LRR7' 'RBR2*'
#  'POC4*' 'HBR2*' 'POC4' 'LCR17000*' 'LCR4YY' 'LRRPD14U*' 'WHR16000PD'
#  'CCR2YY' 'WAR3*' 'R1' 'LCRA*' 'LCR15000*' 'LFR17500*' 'LCRPD10U60'
#  'ARR015' 'LCRA20000*' 'EMR1YY' 'WCR3-MF15*' 'RPRS20000-' 'RERPD6.8U*'
#  'LFR110000*' 'MPR3PD*' 'LARE' 'SRC1CC*' 'SMOP2*' 'GLR1-R*' 'LBR2A'
#  'LBCNR' 'WHR2*' 'WHR175OO*' 'RBCI*' 'LHRA1*' 'SOR1L0' 'LKR1-OS*' 'PDM4'
#  'ESCM*' 'BHR1*' 'DOR171/2' 'BFR3*' '1NR1*' 'LBCCA' 'WVRPD17U*' 'MORF*'
#  'SDSP5*' 'EMR2YY' 'AZCBD*' 'EMR1BY' 'WHM1*' 'WHR4UD*' 'LCRA10' 'LRR17000'
#  'LRRR-1*' 'ESR3YY' 'WDR3A*' 'LAM3' 'BLR1YY' 'RBC1*' 'EMR4*' 'DOR110000*'
#  'EMR1B*' 'LCRAYY' 'LVPR3D*' 'PRCG-P*' 'NOR3*' 'LBRR2I' 'SSR1*' 'RERPD2U*'
#  'NOSP3-SP4-' 'BUR3*' 'LCR16500*' 'WVRPD112U*' 'SDSF9000*' 'LBCMR' 'CUR1*'
#  'POR17500*' 'PDRPD*' 'LCA210' 'RBR2YY' 'LPR106' 'AHR26250*' 'SDRA7500*'
#  'BHR1YY' 'RBR-2' 'MPR2YY' 'HPR2YY' 'WHR2YY' 'LRRPD70001' 'COCL*' 'LARZ3'
#  'SMOP4*' 'MORPD*' 'POR3' 'WARPD28500' 'LFR115000*' 'WCR120000*'
#  'LCR17200*' 'RERA20000*' 'MNR3PD*' 'POCIND*' 'BFR1*' 'CVR171/2'
#  'RPRM5400*' 'PAR16000*' 'LAR4(PV)' 'CCR1YY' 'PDR16000*' 'RPRS8000*'
#  'AHRS-2-200' 'CERS6500' 'PDRPD6.6U*' 'DOR2*' 'CVR17500PC' 'GAR4' 'ESR3*'
#  'CCR2*' 'LVPR6A*' 'LRR16000*' 'LNR2*' 'SHSP' 'PDR110000D' 'RERR-LM'
#  'BRR120000*' 'RHRAS2' 'AZR3C*' 'BUR2*' 'LRRA1OOOO-' 'LCR3DP*' 'DOR175'
#  'CVC3' 'LCRA5000*' 'LCRA1OOOO-' 'CARM18U&D*' 'POR106' 'WVRPD12U*'
#  'WAR18500RU' 'RBR4YY' 'RPRS10000S' 'SMR4*' 'LBPD14' 'LBR4H' 'PDRPD10U*'
#  'LCRA12000*' 'LCR120' 'PDA22*' 'DUR4*' 'NOC3-SPA6*' 'CSCR-SC-RM' 'TCR1YY'
#  'LNR1*' 'GAESSP' 'WH R1*' 'LR16OOO*' 'LCRPD-5000' 'LFR120*' 'WCRA'
#  'LCA121/2*' 'WAR115000R' 'TCR2*' 'CLRM4000*' 'PDR17OOO*' 'CCR1*'
#  'MNR4D46*' 'PDR120000*' 'LAM2' 'AH RM-CD*' 'LCR19000*' 'LASED' 'MPO/'
#  'WAR18500*' 'LR7000' 'SGR17500SI' 'SFR3*' 'LVPR4.5D*' 'SOR110' 'LARZ4'
#  'LCR110' 'SER3*' 'LBR2I' 'TCRI7200*' 'LCRA07' 'LCRPD13.8U' 'LCA21-A110'
#  'LCR110000-' 'CORAYY' 'GLR2YY' 'LCRA7OOO' 'WHR110000*' 'PDR1 7000'
#  'TOR3*' 'POR171/2' 'SHR3*' 'TORR-LM' 'PAR2*' 'POR31500S*' 'AHR17500*'
#  'LBPD' 'LCM1YY' 'PDR1-10000' 'PDR1' 'GAR2' 'SRR1-CUP*' 'CLRM*' 'PDR3*'
#  'CVC3*' 'SPR2A10000' 'HAM2*' 'PDRPD-1-12' 'SDSF10000*' 'LRRA6500' 'WHC1*'
#  'HGR3*' 'GDE7-40,00' 'WHR110' 'WHR1L2' 'LCRPD1-2U*' 'WARPD12300'
#  'ARR112500*' 'LCM2*' 'AZM2*' 'SLR1A*' 'WVRR1-RPD1' 'AZW*' 'HAR4*' 'CORA*'
#  'CLRS*' 'PSRM32*' 'LCRPD6OOO5' 'LR-R1OOOO*' 'SDSF6000*' 'LAM1' 'ARR0YY'
#  'LOA1*' 'SMR3*' 'WHHR*' 'GDM1A*' 'LRRR1*' 'DOM1' 'AHRPD10000' 'ALR1YY'
#  'LCR12L' 'WHR11L' 'LCRPD 1000' 'INR1*' 'AZR3*' 'LOCG' 'SDM1*' 'LCRPD6000'
#  'LCC3VV' 'PSR6*' 'NOR3YY' 'SDR115000*' 'SLR3YY' 'BFA1*' 'LCR2DP*'
#  'CVR120000*' 'WCMF8*' 'EMR3F*' 'HPCM*' 'LARZ5' 'CVC3APCD*' 'MPR3YY'
#  'LCM1DP*' 'LACR' 'CUR3*' 'COR2*' 'RBPDC*' 'PAM1*' 'DOR2&HFB*' 'LAC15000*'
#  'POR23000*' '1NR3*' 'ESR2*' 'INP1*' 'RERA10000*' 'LRRPD70008' 'LPR1*'
#  'LCC1-RA100' 'LCR3800015' 'SDRA71/2' 'ESR2YY' 'LAMR1' 'RPRM3600*'
#  'LCA17500*' 'ESM1*' 'LCD21*' 'LCR101' 'SDSF5000*' 'LBCB' 'LBCC'
#  'LCR440U*' 'RBPI' 'LCR17500ED' 'BHR475*' 'LCR11*' 'LCA21-A11*'
#  'LCA120000*' 'LVRSP86-16' 'LBCB*' 'LAA2' 'DOHM*' 'DUR410000*' 'AHRPD10*'
#  'RPRAIA*' 'ARR110000D' 'AZR3A*' 'LKOS*' 'GDR_VIL_GR' 'EMRIB*' 'PDRI'
#  'LCRPD70001' 'TOHC-CTR' 'LFR140000*' 'WCR19450-R' 'TODC-CTR' 'RBR3YY'
#  'LNR3*' 'DUR3*' 'LMRI' 'CC-R3' 'LCC2-CH*' 'LCR326UDP*' 'LAP' 'DOR18500*'
#  'SGR3*' 'WVR16000*' 'WCRA*' 'LBPD17']

# %%
plt.figure(figsize=(8, 5))
sb.distplot(df['target'])
plt.show()

# %%
plt.figure(figsize=(8, 5))
sb.boxplot(df['target'])
plt.show()

# %%
print('Shape of the dataframe before removal of outliers', df.shape)
df = df[(df['target'] > -1) & (df['target'] < 1)]
print('Shape of the dataframe after removal of outliers ', df.shape)
# Out:
# Shape of the dataframe before removal of outliers (8599, 29)
# Shape of the dataframe after removal of outliers  (8566, 29)

# %%
for col in objects:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
plt.figure(figsize=(15, 15))
sb.heatmap(df.corr() > 0.8,
           annot=True,
           cbar=False)
plt.show()

# %%
to_remove = ['calculatedbathnbr', 'fullbathcnt', 'fips',
             'rawcensustractandblock', 'taxvaluedollarcnt',
             'finishedsquarefeet12', 'landtaxvaluedollarcnt']

df.drop(to_remove, axis=1, inplace=True)

# %%
features = df.drop(['parcelid'], axis=1)
target = df['target'].values

X_train, X_val,\
    Y_train, Y_val = train_test_split(features, target,
                                      test_size=0.1,
                                      random_state=22)
X_train.shape, X_val.shape
# Out:
# ((7709, 21), (857, 21))

# %%
# Normalizing the features for stable and fast training.
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %%
from sklearn.metrics import mean_absolute_error as mae
models = [LinearRegression(), XGBRegressor(),
          Lasso(), RandomForestRegressor(), Ridge()]

for i in range(5):
    models[i].fit(X_train, Y_train)

    print(f'{models[i]} : ')

    train_preds = models[i].predict(X_train)
    print('Training Error : ', mae(Y_train, train_preds))

    val_preds = models[i].predict(X_val)
    print('Validation Error : ', mae(Y_val, val_preds))
    print()
# Out:
# LinearRegression() :
# Training Error :  1.0555955624638234e-16
# Validation Error :  1.0252239206922776e-16
#
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...) :
# Training Error :  0.0005506970148793896
# Validation Error :  0.002395868761715248
#
# Lasso() :
# Training Error :  0.06804439806766967
# Validation Error :  0.06766357941743958
#
# RandomForestRegressor() :
# Training Error :  8.592777356077526e-05
# Validation Error :  0.00018931325940968954
#
# Ridge() :
# Training Error :  8.933112240829643e-06
# Validation Error :  8.854894215306487e-06
